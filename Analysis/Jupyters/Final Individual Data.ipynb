# %% [markdown]
# # Raw Individual Results

# %%
library(MCMCglmm)
library(tidyverse)
# Out:
# Loading required package: Matrix
#
# Loading required package: coda
#
# Loading required package: ape
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.0.4     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ tidyr::expand() masks Matrix::expand()
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ✖ tidyr::pack()   masks Matrix::pack()
# ✖ tidyr::unpack() masks Matrix::unpack()

# %% [markdown]
# ## Day 12 Mass

# %%
Vect <- c(1,7,13,19,25,31)
for(i in 1:length(Vect)){
load(paste("../FinalResults/IndivModel_",Vect[i],".rda", sep=""))
print(summary(Model))
}
# Out:
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 10461.78
#
#  G-structure:  ~MaleID
#
#        post.mean l-95% CI u-95% CI eff.samp
# MaleID     0.976   0.2405    1.738     9337
#
#                ~FemaleID
#
#          post.mean l-95% CI u-95% CI eff.samp
# FemaleID    0.4303  0.00026    1.105     7810
#
#                ~RearBrood
#
#           post.mean l-95% CI u-95% CI eff.samp
# RearBrood     3.839    2.907    4.796     9900
#
#                ~Year
#
#      post.mean l-95% CI u-95% CI eff.samp
# Year    0.7723   0.1105    1.707     8525
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location    0.0503 0.0001938   0.2141     9594
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units     8.799    8.077     9.51    10332
#
#  Location effects: Day12Mass ~ z_AvgFeedRateChick + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                          post.mean  l-95% CI  u-95% CI eff.samp    pMCMC
# (Intercept)               22.62513  21.47142  23.76512     9900  < 1e-04 ***
# z_AvgFeedRateChick         0.26216   0.02142   0.49501     9900 0.031111 *
# Sex                        0.59548   0.29727   0.89169    10718  < 1e-04 ***
# MaleAge                    0.12168  -0.05819   0.30624     9900 0.190101
# FemaleAge                  0.01539  -0.18206   0.20412     9900 0.876162
# HatchBroodSize            -0.39137  -0.60881  -0.16567     9553 0.000202 ***
# poly(HatchBroodSize, 2)2  -7.65657 -16.43374   0.21642     9345 0.070303 .
# poly(HatchDateCode, 2)1   33.50092  23.78764  43.04795     9900  < 1e-04 ***
# poly(HatchDateCode, 2)2  -26.49501 -36.22449 -17.40576     9900  < 1e-04 ***
# Fostered                   0.55732   0.13447   0.98823     9900 0.012525 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 10051.67
#
#  G-structure:  ~MaleID
#
#        post.mean l-95% CI u-95% CI eff.samp
# MaleID    0.9571   0.2222    1.727    10115
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID    0.4622 0.0001129    1.127     7539
#
#                ~RearBrood
#
#           post.mean l-95% CI u-95% CI eff.samp
# RearBrood     3.526    2.574    4.498     9603
#
#                ~Year
#
#      post.mean l-95% CI u-95% CI eff.samp
# Year    0.8496   0.1471     1.87     9900
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location   0.04425 0.0001791   0.1799     9900
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units     8.854    8.122    9.612     9540
#
#  Location effects: Day12Mass ~ z_FeedRateChick7 + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                           post.mean   l-95% CI   u-95% CI eff.samp   pMCMC
# (Intercept)               22.481078  21.292606  23.638368    10198 < 1e-04 ***
# z_FeedRateChick7           0.361563   0.123609   0.593065     9900 0.00242 **
# Sex                        0.627637   0.327559   0.937767     9900 < 1e-04 ***
# MaleAge                    0.165467  -0.008175   0.353293     9834 0.07293 .
# FemaleAge                  0.024866  -0.173769   0.219011     9900 0.80586
# HatchBroodSize            -0.381493  -0.617538  -0.172257     9900 0.00202 **
# poly(HatchBroodSize, 2)2  -9.243258 -18.045456  -1.100778     9900 0.03354 *
# poly(HatchDateCode, 2)1   32.097186  22.956440  41.372120     9546 < 1e-04 ***
# poly(HatchDateCode, 2)2  -24.755151 -34.165541 -15.860664     9582 < 1e-04 ***
# Fostered                   0.472921   0.051938   0.910535     9900 0.03293 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 9337.51
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID    0.9425 0.0003063    1.663     9226
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID      0.72 0.0003224     1.52     8451
#
#                ~RearBrood
#
#           post.mean l-95% CI u-95% CI eff.samp
# RearBrood     3.817    2.768    4.894     9451
#
#                ~Year
#
#      post.mean l-95% CI u-95% CI eff.samp
# Year    0.8353   0.1289    1.883     9900
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location   0.05016 0.0001585   0.2159     9768
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units     8.367    7.662    9.134     9513
#
#  Location effects: Day12Mass ~ z_FeedRateChick11 + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                           post.mean   l-95% CI   u-95% CI eff.samp    pMCMC
# (Intercept)               22.493937  21.295084  23.707177     9669  < 1e-04 ***
# z_FeedRateChick11          0.133354  -0.101014   0.374720     9900 0.270707
# Sex                        0.593701   0.296837   0.908867    10165 0.000404 ***
# MaleAge                    0.196591   0.001271   0.392630     9900 0.048687 *
# FemaleAge                 -0.009055  -0.212141   0.206649     9900 0.934545
# HatchBroodSize            -0.372631  -0.592619  -0.141260     9900 0.000404 ***
# poly(HatchBroodSize, 2)2  -7.237069 -15.385232   1.287017     9872 0.094747 .
# poly(HatchDateCode, 2)1   31.592568  21.810164  41.114208     9900  < 1e-04 ***
# poly(HatchDateCode, 2)2  -29.053636 -38.643090 -19.863007     9852  < 1e-04 ***
# Fostered                   0.450074   0.020228   0.915769     9900 0.048283 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 8093.201
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID    0.1578 0.0001994   0.6018     8247
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID    0.5232 0.0002136    1.175     8351
#
#                ~RearBrood
#
#           post.mean l-95% CI u-95% CI eff.samp
# RearBrood     3.657    2.583    4.778     9900
#
#                ~Year
#
#      post.mean l-95% CI u-95% CI eff.samp
# Year     1.253   0.1895    3.016     9900
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location   0.06063 0.0001255    0.273     9900
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units     9.451    8.568    10.37     9900
#
#  Location effects: Day12Mass ~ z_AvgMeerkatRateChick + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                           post.mean   l-95% CI   u-95% CI eff.samp   pMCMC
# (Intercept)               21.994648  20.692749  23.296819     9900 < 1e-04 ***
# z_AvgMeerkatRateChick     -0.004268  -0.267005   0.247759     9900 0.97616
# Sex                        0.565756   0.212920   0.914221     9900 0.00101 **
# MaleAge                    0.116186  -0.049972   0.292484     9900 0.19455
# FemaleAge                 -0.042819  -0.220972   0.113079     9900 0.62141
# HatchBroodSize            -0.326714  -0.562654  -0.074288    10471 0.00586 **
# poly(HatchBroodSize, 2)2  -3.723234 -12.082120   4.314940     9900 0.37354
# poly(HatchDateCode, 2)1   24.783537  14.439382  34.093197     9900 < 1e-04 ***
# poly(HatchDateCode, 2)2  -13.500800 -23.079866  -3.898148     9900 0.00465 **
# Fostered                   0.709161   0.274678   1.138986     9900 0.00202 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 7841.312
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID    0.1825 0.0002001   0.7091     8523
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID    0.9602 0.0003465    1.698     8780
#
#                ~RearBrood
#
#           post.mean l-95% CI u-95% CI eff.samp
# RearBrood     3.267     2.25    4.355     9900
#
#                ~Year
#
#      post.mean l-95% CI u-95% CI eff.samp
# Year     1.646   0.2271    3.865     9900
#
#                ~Location
#
#          post.mean l-95% CI u-95% CI eff.samp
# Location   0.07577 0.000146   0.3299     9645
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units     9.154    8.298    10.05     9900
#
#  Location effects: Day12Mass ~ z_MeerkatRateChick7 + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                          post.mean  l-95% CI  u-95% CI eff.samp    pMCMC
# (Intercept)               21.57742  20.16888  22.94384     9900  < 1e-04 ***
# z_MeerkatRateChick7        0.02451  -0.23597   0.28968     9900 0.869091
# Sex                        0.58884   0.25073   0.94850     9658 0.000606 ***
# MaleAge                    0.12462  -0.05054   0.30071     9900 0.170303
# FemaleAge                 -0.02373  -0.20216   0.15504     9900 0.804242
# HatchBroodSize            -0.25958  -0.48873  -0.01068     9900 0.032929 *
# poly(HatchBroodSize, 2)2  -3.11766 -11.56505   4.94321     9900 0.450303
# poly(HatchDateCode, 2)1   24.46640  14.35643  33.64827     9900  < 1e-04 ***
# poly(HatchDateCode, 2)2  -14.02046 -23.48754  -4.49416     9900 0.004646 **
# Fostered                   0.86104   0.43795   1.31643     9900 0.000404 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 8036.399
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID     0.217 0.0002075   0.7535     8080
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID    0.5239 0.0002556    1.183     8219
#
#                ~RearBrood
#
#           post.mean l-95% CI u-95% CI eff.samp
# RearBrood     3.645    2.605    4.786    10964
#
#                ~Year
#
#      post.mean l-95% CI u-95% CI eff.samp
# Year     1.195   0.1226    2.875     9900
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location   0.07953 0.0001501   0.3287     9900
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units     9.137    8.275    10.02     9900
#
#  Location effects: Day12Mass ~ z_MeerkatRateChick11 + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                           post.mean   l-95% CI   u-95% CI eff.samp   pMCMC
# (Intercept)               21.924373  20.613462  23.202109     9900 < 1e-04 ***
# z_MeerkatRateChick11      -0.004888  -0.259041   0.234727    10709 0.98121
# Sex                        0.515579   0.167130   0.870082     9900 0.00545 **
# MaleAge                    0.093786  -0.065839   0.267319     9908 0.26788
# FemaleAge                 -0.029505  -0.197657   0.144375     9900 0.73939
# HatchBroodSize            -0.299638  -0.542902  -0.069684     9900 0.01636 *
# poly(HatchBroodSize, 2)2  -4.104057 -12.187231   3.963911     9600 0.32768
# poly(HatchDateCode, 2)1   25.596005  15.864251  35.221285     9900 < 1e-04 ***
# poly(HatchDateCode, 2)2  -12.870007 -22.598346  -3.451646     9900 0.00626 **
# Fostered                   0.704409   0.270268   1.141718     9900 0.00141 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# ## Survival Till Fledged

# %%
Vect <- c(2,8,14,20,26,32)

for(i in 1:length(Vect)){
load(paste("../FinalResults/IndivModel_",Vect[i],".rda", sep=""))
print(summary(Model))
}
# Out:
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 88.79305
#
#  G-structure:  ~MaleID
#
#        post.mean l-95% CI u-95% CI eff.samp
# MaleID     335.5 0.000142     1408     3177
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID     30.93 0.0002043    176.8     4616
#
#                ~RearBrood
#
#           post.mean l-95% CI u-95% CI eff.samp
# RearBrood      9207     4399    13845     7249
#
#                ~Year
#
#      post.mean l-95% CI u-95% CI eff.samp
# Year     13933     3126    30146     9614
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location     13.99 0.0002007    68.49     9900
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units     24704    13235    34973     6996
#
#  Location effects: SurvFledge ~ z_AvgFeedRateChick + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                           post.mean   l-95% CI   u-95% CI eff.samp    pMCMC
# (Intercept)                -76.3842  -159.9747     5.4749     9602 0.064848 .
# z_AvgFeedRateChick           1.7491    -8.8241    11.9036     9900 0.731515
# Sex                         13.6302    -1.9036    30.8511     9523 0.091111 .
# MaleAge                      6.8246    -0.5646    14.5349     9900 0.072323 .
# FemaleAge                    2.3139    -6.2142    10.8829     9900 0.594141
# HatchBroodSize               0.2347    -9.6169    10.3504     9900 0.962222
# poly(HatchBroodSize, 2)2  -890.0882 -1495.9463  -321.2695     9131 0.001616 **
# poly(HatchDateCode, 2)1   1073.0390   423.3499  1725.2799     9180 0.000202 ***
# poly(HatchDateCode, 2)2  -1372.5400 -2080.7542  -748.3910     8806  < 1e-04 ***
# Fostered                   104.3113    74.8396   135.8832     7273  < 1e-04 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 84.57151
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID       417 0.0002071     1616     2404
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID     34.81 0.0001786    196.3     4929
#
#                ~RearBrood
#
#           post.mean l-95% CI u-95% CI eff.samp
# RearBrood      8718     4218    13319     6923
#
#                ~Year
#
#      post.mean l-95% CI u-95% CI eff.samp
# Year     14554     2480    30768     9549
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location     13.79 0.0001693    68.64     9900
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units     24808    13510    35732     6768
#
#  Location effects: SurvFledge ~ z_FeedRateChick7 + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                           post.mean   l-95% CI   u-95% CI eff.samp    pMCMC
# (Intercept)                -85.8101  -172.0064    -0.2133     9091 0.045657 *
# z_FeedRateChick7             6.3627    -3.9408    17.3019     9900 0.236768
# Sex                         16.9833    -0.6772    33.0319     9900 0.043636 *
# MaleAge                      5.8434    -1.5323    13.3853     9900 0.115354
# FemaleAge                    0.4874    -7.8993     9.0509     9979 0.922626
# HatchBroodSize               4.1560    -5.9602    14.6832     9900 0.429495
# poly(HatchBroodSize, 2)2  -987.9006 -1576.7600  -385.1431     8578 0.000202 ***
# poly(HatchDateCode, 2)1   1106.7736   475.1438  1767.3207     9032 0.000404 ***
# poly(HatchDateCode, 2)2  -1503.5019 -2216.7371  -813.6141     8413  < 1e-04 ***
# Fostered                   106.8191    74.8252   137.0991     7795  < 1e-04 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 76.72231
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID     197.5 0.0001987     1113     3864
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID     34.64 0.0001988    202.1     5019
#
#                ~RearBrood
#
#           post.mean l-95% CI u-95% CI eff.samp
# RearBrood      8867     4278    13561     7704
#
#                ~Year
#
#      post.mean l-95% CI u-95% CI eff.samp
# Year     14485     2872    30836     9558
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location     19.05 0.0001895    96.23     9900
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units     25093    13562    35811     7160
#
#  Location effects: SurvFledge ~ z_FeedRateChick11 + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                           post.mean   l-95% CI   u-95% CI eff.samp    pMCMC
# (Intercept)                -60.7969  -153.2097    18.2449     9900 0.141818
# z_FeedRateChick11           -7.7812   -19.3430     2.9284     9900 0.155354
# Sex                          8.0071    -8.9578    25.5455     9900 0.353131
# MaleAge                      9.4924     1.0749    17.3578     9900 0.014343 *
# FemaleAge                    0.2763    -8.8190     9.0792     9900 0.953535
# HatchBroodSize               0.2901    -9.8450    11.0183     9900 0.951111
# poly(HatchBroodSize, 2)2  -925.2521 -1512.8128  -332.6692     9196 0.001010 **
# poly(HatchDateCode, 2)1   1063.6247   420.4361  1707.3873     9900 0.000606 ***
# poly(HatchDateCode, 2)2   -874.5324 -1488.1048  -251.8240     8687 0.002222 **
# Fostered                    91.7504    61.9565   120.7185     8460  < 1e-04 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 45.14053
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID     55.41 0.0001603    321.3     6963
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID     63.85 0.0002251    380.8     6243
#
#                ~RearBrood
#
#           post.mean l-95% CI u-95% CI eff.samp
# RearBrood      7402     1986    12993     7717
#
#                ~Year
#
#      post.mean l-95% CI u-95% CI eff.samp
# Year     14674     2065    34839     9205
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location     331.3 0.0002672     1705     9900
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units     44128    21921    64419     7706
#
#  Location effects: SurvFledge ~ z_AvgMeerkatRateChick + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                          post.mean  l-95% CI  u-95% CI eff.samp    pMCMC
# (Intercept)               -255.918  -373.656  -135.034     9407  < 1e-04 ***
# z_AvgMeerkatRateChick       12.192    -1.826    28.035     9900 0.098182 .
# Sex                          7.490   -17.894    33.143     9900 0.555758
# MaleAge                      4.092    -6.402    14.295     9900 0.428081
# FemaleAge                    4.689    -5.281    15.658     9900 0.384848
# HatchBroodSize              21.773     6.434    36.534     9900 0.001010 **
# poly(HatchBroodSize, 2)2 -1212.501 -2007.815  -415.917     9421 0.000606 ***
# poly(HatchDateCode, 2)1      4.236  -767.328   788.563     9900 0.986869
# poly(HatchDateCode, 2)2  -2834.782 -3847.152 -1802.758     8647  < 1e-04 ***
# Fostered                    31.012     3.701    60.954     9829 0.025455 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 43.87944
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID     126.5 0.0002125    819.9     4918
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID     131.7 0.0002283      791     5088
#
#                ~RearBrood
#
#           post.mean  l-95% CI u-95% CI eff.samp
# RearBrood      5899 0.0006701    10812     1112
#
#                ~Year
#
#      post.mean l-95% CI u-95% CI eff.samp
# Year     14075     2022    33089     9583
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location     845.4 0.0002753     3861     9900
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units     44803    22823    65909     7939
#
#  Location effects: SurvFledge ~ z_MeerkatRateChick7 + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                           post.mean   l-95% CI   u-95% CI eff.samp  pMCMC
# (Intercept)               -223.3220  -337.6414  -109.5280     9900 <1e-04 ***
# z_MeerkatRateChick7          8.7716    -5.6619    23.7679     9662 0.2257
# Sex                         11.6522   -14.1776    37.0434     9443 0.3588
# MaleAge                      4.6318    -5.7059    14.8944     9900 0.3610
# FemaleAge                    2.7145    -8.4318    13.3035     9900 0.6200
# HatchBroodSize              14.7034     0.9273    29.8070     9900 0.0424 *
# poly(HatchBroodSize, 2)2  -756.8016 -1455.2928   -62.0056     9900 0.0273 *
# poly(HatchDateCode, 2)1    -96.2497  -856.3696   637.5284     9900 0.7994
# poly(HatchDateCode, 2)2  -2867.6237 -3837.4689 -1831.5429     8542 <1e-04 ***
# Fostered                    32.0299     3.6537    60.6330     9900 0.0212 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 45.23015
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID     61.09 0.0001862    351.8     6427
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID      56.7 0.0001829    316.3     5916
#
#                ~RearBrood
#
#           post.mean l-95% CI u-95% CI eff.samp
# RearBrood      7521     2384    13103     8695
#
#                ~Year
#
#      post.mean l-95% CI u-95% CI eff.samp
# Year     14349     2205    33956     9900
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location     400.2 0.0001986     2080     9900
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units     43454    22908    64016     8033
#
#  Location effects: SurvFledge ~ z_MeerkatRateChick11 + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                          post.mean  l-95% CI  u-95% CI eff.samp    pMCMC
# (Intercept)               -232.689  -348.926  -118.840     9454 0.000606 ***
# z_MeerkatRateChick11         3.560   -10.831    17.409     9617 0.625455
# Sex                          8.236   -17.079    32.802     9900 0.520000
# MaleAge                      6.977    -3.175    17.681     9900 0.175960
# FemaleAge                    1.852    -8.900    11.877     9900 0.724444
# HatchBroodSize              16.768     1.979    30.961     9469 0.015152 *
# poly(HatchBroodSize, 2)2 -1054.420 -1835.043  -321.159     9900 0.003030 **
# poly(HatchDateCode, 2)1    -38.082  -781.408   709.339     9900 0.935556
# poly(HatchDateCode, 2)2  -2640.332 -3584.535 -1666.690     8968  < 1e-04 ***
# Fostered                    31.844     3.706    60.591     9900 0.021414 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# ## Recruited or not

# %%
Vect <- c(5,11,17,23,29,35)
for(i in 1:length(Vect)){
load(paste("../FinalResults/IndivModel_",Vect[i],".rda", sep=""))
print(summary(Model))
}
# Out:
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 32.80195
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID      3756 0.0002903     8738     2301
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID     111.2 0.0002418    657.3     5209
#
#                ~RearBrood
#
#           post.mean l-95% CI u-95% CI eff.samp
# RearBrood     12303     3504    23554     3747
#
#                ~Year
#
#      post.mean l-95% CI u-95% CI eff.samp
# Year     30494     5628    65558     8292
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location     106.7 0.0002255      572     9900
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units     57963    28568    88259     4770
#
#  Location effects: Recruited ~ z_AvgFeedRateChick + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                          post.mean  l-95% CI  u-95% CI eff.samp    pMCMC
# (Intercept)               -362.759  -521.775  -202.137     6992 0.000202 ***
# z_AvgFeedRateChick           1.522   -17.698    21.066     9900 0.879192
# Sex                         16.635   -13.919    46.805     9248 0.273131
# MaleAge                      9.757    -3.671    25.335     8614 0.166061
# FemaleAge                    6.329    -9.457    22.389     8767 0.422424
# HatchBroodSize               2.775   -14.619    22.556     9289 0.767677
# poly(HatchBroodSize, 2)2 -1093.399 -2233.438   -89.264     9305 0.034343 *
# poly(HatchDateCode, 2)1    731.919  -343.036  1892.249     9507 0.181818
# poly(HatchDateCode, 2)2  -2362.539 -3598.263 -1088.015     7588  < 1e-04 ***
# Fostered                    33.606    -5.094    70.032     9242 0.070909 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 30.6767
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID      3692 0.0004026     9010     1906
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID     100.1 0.0002179    582.9     4668
#
#                ~RearBrood
#
#           post.mean  l-95% CI u-95% CI eff.samp
# RearBrood     10518 0.0004473    20073     1687
#
#                ~Year
#
#      post.mean l-95% CI u-95% CI eff.samp
# Year     32985     6953    71417     9048
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location     129.8 0.0002523    686.7     9900
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units     60789    27616    92008     5040
#
#  Location effects: Recruited ~ z_FeedRateChick7 + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                          post.mean  l-95% CI  u-95% CI eff.samp    pMCMC
# (Intercept)               -389.311  -559.031  -213.672     7009  < 1e-04 ***
# z_FeedRateChick7            14.426    -4.604    35.442     9415 0.138788
# Sex                         22.116   -10.045    54.049     9900 0.169495
# MaleAge                      7.906    -6.894    22.485     9900 0.281818
# FemaleAge                    2.357   -14.970    18.356     9356 0.770505
# HatchBroodSize              12.470    -6.590    32.577     9900 0.197172
# poly(HatchBroodSize, 2)2 -1201.626 -2307.633   -57.126     9341 0.024848 *
# poly(HatchDateCode, 2)1    653.689  -477.579  1765.899     9900 0.239192
# poly(HatchDateCode, 2)2  -2217.672 -3503.262 -1005.059     7572 0.000202 ***
# Fostered                    37.814    -1.136    76.176     8635 0.043030 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 29.40748
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID      2972 0.0002171     8138     1561
#
#                ~FemaleID
#
#          post.mean l-95% CI u-95% CI eff.samp
# FemaleID     192.2  0.00016     1179     3854
#
#                ~RearBrood
#
#           post.mean  l-95% CI u-95% CI eff.samp
# RearBrood      9936 0.0005042    19441     1152
#
#                ~Year
#
#      post.mean l-95% CI u-95% CI eff.samp
# Year     30835     5608    66811     8554
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location     80.17 0.0001952      375     9900
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units     59559    27308    90472     5153
#
#  Location effects: Recruited ~ z_FeedRateChick11 + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                          post.mean  l-95% CI  u-95% CI eff.samp    pMCMC
# (Intercept)               -326.849  -482.898  -167.889     7466  < 1e-04 ***
# z_FeedRateChick11          -14.176   -34.786     5.597     9900 0.160404
# Sex                          9.986   -21.246    43.482     9900 0.527879
# MaleAge                      9.017    -6.016    24.426     9900 0.230707
# FemaleAge                    9.430    -6.745    25.979     9900 0.249495
# HatchBroodSize              -3.550   -23.227    15.053     9564 0.707475
# poly(HatchBroodSize, 2)2 -1189.210 -2233.510  -160.101     8583 0.016364 *
# poly(HatchDateCode, 2)1    978.169  -104.410  2054.508     9900 0.072121 .
# poly(HatchDateCode, 2)2  -1819.018 -2982.860  -689.304     7445 0.000606 ***
# Fostered                    19.888   -16.629    59.262     9181 0.311919
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 20.70917
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID     179.7 0.0002163     1086     5079
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID     82.79 0.0002136    455.2     6596
#
#                ~RearBrood
#
#           post.mean l-95% CI u-95% CI eff.samp
# RearBrood     18309     5203    32720     8239
#
#                ~Year
#
#      post.mean l-95% CI u-95% CI eff.samp
# Year     61512     6564   156236     9364
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location     215.1 0.0001969     1022     9900
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units     70496    33035   107678     5871
#
#  Location effects: Recruited ~ z_AvgMeerkatRateChick + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                           post.mean   l-95% CI   u-95% CI eff.samp   pMCMC
# (Intercept)               -558.6196  -816.1599  -321.5804     7328 < 1e-04 ***
# z_AvgMeerkatRateChick        5.1622   -18.4241    29.5126     9900 0.67131
# Sex                          0.5320   -40.4404    42.2917     9900 0.97394
# MaleAge                      7.3044    -9.1524    24.5465     9900 0.38444
# FemaleAge                    0.6011   -17.5221    18.1102    11778 0.94404
# HatchBroodSize              34.9372     9.6541    61.1036     8416 0.00485 **
# poly(HatchBroodSize, 2)2 -1662.9106 -3068.3169  -342.4048     9002 0.00929 **
# poly(HatchDateCode, 2)1   -343.2154 -1609.3603   911.8448     9900 0.58687
# poly(HatchDateCode, 2)2  -1839.2077 -3141.0293  -655.4860     8724 0.00101 **
# Fostered                    11.0962   -33.3879    56.7333     9486 0.61717
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 19.824
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID     276.3 0.0002032     1661     5730
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID     76.99 0.0001974    428.8     6904
#
#                ~RearBrood
#
#           post.mean  l-95% CI u-95% CI eff.samp
# RearBrood     15395 0.0006885    28584     3856
#
#                ~Year
#
#      post.mean l-95% CI u-95% CI eff.samp
# Year     62327     6162   161749     9642
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location     190.3 0.0001506    748.8     9094
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units     74130    34524   114763     5293
#
#  Location effects: Recruited ~ z_MeerkatRateChick7 + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                          post.mean  l-95% CI  u-95% CI eff.samp   pMCMC
# (Intercept)               -562.304  -815.542  -316.825     6916 < 1e-04 ***
# z_MeerkatRateChick7         16.882    -7.378    41.685    10102 0.16424
# Sex                         -1.517   -43.144    38.821     9543 0.95737
# MaleAge                      8.772    -7.934    26.321     9900 0.30808
# FemaleAge                   -2.563   -20.357    15.848     9900 0.78909
# HatchBroodSize              38.125    12.454    66.465     8955 0.00182 **
# poly(HatchBroodSize, 2)2 -1589.444 -2908.757  -339.311     8999 0.00869 **
# poly(HatchDateCode, 2)1   -299.345 -1536.789   922.457     9900 0.62687
# poly(HatchDateCode, 2)2  -2149.502 -3488.420  -873.247     7950 < 1e-04 ***
# Fostered                    10.842   -36.102    57.987     9900 0.64525
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 20.59838
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID     193.3 0.0001664     1159     5422
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID     89.85 0.0001405      518     6529
#
#                ~RearBrood
#
#           post.mean l-95% CI u-95% CI eff.samp
# RearBrood     15691     4080    30092     7258
#
#                ~Year
#
#      post.mean l-95% CI u-95% CI eff.samp
# Year     62463     6960   162462     8301
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location     203.8 0.0002695    829.2     9900
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units     72675    34645   113007     4922
#
#  Location effects: Recruited ~ z_MeerkatRateChick11 + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                          post.mean  l-95% CI  u-95% CI eff.samp    pMCMC
# (Intercept)               -552.265  -809.263  -316.996     6391 0.000202 ***
# z_MeerkatRateChick11        -2.913   -25.974    19.402     9900 0.812323
# Sex                          1.660   -40.361    42.251     9900 0.925253
# MaleAge                      9.734    -6.912    26.348     9920 0.245253
# FemaleAge                   -1.560   -19.318    15.659     9900 0.869495
# HatchBroodSize              33.404     7.445    59.524     8543 0.006667 **
# poly(HatchBroodSize, 2)2 -1764.373 -3207.157  -469.315     9266 0.004646 **
# poly(HatchDateCode, 2)1   -234.009 -1522.973   950.030     9355 0.716970
# poly(HatchDateCode, 2)2  -1844.236 -3056.125  -632.436     7454 0.001010 **
# Fostered                    13.145   -33.480    57.370     9900 0.561010
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# ## Longevity

# %%
Vect <- c(3,9,15,21,27,33)

for(i in 1:length(Vect)){
load(paste("../FinalResults/IndivModel_",Vect[i],".rda", sep=""))
print(summary(Model))
}
# Out:
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 3401.739
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID    0.2053 0.0002621   0.4213     9582
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID   0.02432 0.0001532  0.09757     9757
#
#                ~RearBrood
#
#           post.mean l-95% CI u-95% CI eff.samp
# RearBrood    0.7073   0.3262    1.096     9565
#
#                ~Year
#
#      post.mean l-95% CI u-95% CI eff.samp
# Year     1.453    0.398    2.971     9900
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location   0.02017 0.0001716  0.08003     9900
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units     1.517    1.104    1.907     9900
#
#  Location effects: Longevity ~ z_AvgFeedRateChick + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                           post.mean   l-95% CI   u-95% CI eff.samp    pMCMC
# (Intercept)               -2.961586  -3.839809  -1.994433     9900  < 1e-04 ***
# z_AvgFeedRateChick        -0.022803  -0.156428   0.122175     8592 0.741616
# Sex                        0.264934   0.060197   0.470942     9900 0.013535 *
# MaleAge                    0.052202  -0.052280   0.155412     9976 0.340404
# FemaleAge                  0.064719  -0.048015   0.174362     9900 0.259596
# HatchBroodSize            -0.008594  -0.135349   0.120978     9900 0.903030
# poly(HatchBroodSize, 2)2  -5.779304 -13.220675   1.410713     9900 0.119596
# poly(HatchDateCode, 2)1    1.922394  -5.754718   9.584489     9734 0.613333
# poly(HatchDateCode, 2)2  -13.623351 -21.266409  -6.240304     9110 0.000404 ***
# Fostered                   0.320760   0.068299   0.591131     9581 0.015354 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 3176.421
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID    0.1821 0.0002827   0.4047     9052
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID   0.02367 0.0001188  0.09491     9419
#
#                ~RearBrood
#
#           post.mean l-95% CI u-95% CI eff.samp
# RearBrood    0.6961   0.2965    1.096     9582
#
#                ~Year
#
#      post.mean l-95% CI u-95% CI eff.samp
# Year     1.563   0.4635    3.328     9900
#
#                ~Location
#
#          post.mean l-95% CI u-95% CI eff.samp
# Location    0.0259 0.000161   0.1063     9900
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units     1.646     1.22    2.118    10770
#
#  Location effects: Longevity ~ z_FeedRateChick7 + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                          post.mean  l-95% CI  u-95% CI eff.samp   pMCMC
# (Intercept)               -3.11717  -4.07506  -2.16016     9900 < 1e-04 ***
# z_FeedRateChick7           0.02431  -0.12710   0.15963     9168 0.73475
# Sex                        0.29949   0.08227   0.51686    10339 0.00808 **
# MaleAge                    0.04266  -0.06658   0.14672    10355 0.42929
# FemaleAge                  0.05508  -0.05194   0.17458     9900 0.35111
# HatchBroodSize             0.02459  -0.11310   0.16337     9900 0.73152
# poly(HatchBroodSize, 2)2  -6.98875 -14.39322   0.68266     9900 0.07111 .
# poly(HatchDateCode, 2)1    2.09746  -5.79173   9.69222     9593 0.59071
# poly(HatchDateCode, 2)2  -14.20266 -22.33016  -6.53246     9900 < 1e-04 ***
# Fostered                   0.35560   0.08467   0.61577     9621 0.00727 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 3075.989
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID    0.1119 0.0002112   0.2966     8504
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID   0.02922 0.0001508   0.1156     9274
#
#                ~RearBrood
#
#           post.mean l-95% CI u-95% CI eff.samp
# RearBrood     0.661   0.3069    1.065     9420
#
#                ~Year
#
#      post.mean l-95% CI u-95% CI eff.samp
# Year     1.394   0.3755    2.815     9900
#
#                ~Location
#
#          post.mean l-95% CI u-95% CI eff.samp
# Location   0.01711 0.000148  0.06637     9900
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units     1.486    1.084    1.906     9900
#
#  Location effects: Longevity ~ z_FeedRateChick11 + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                           post.mean   l-95% CI   u-95% CI eff.samp   pMCMC
# (Intercept)               -2.729497  -3.691814  -1.833955     9729 < 1e-04 ***
# z_FeedRateChick11         -0.108606  -0.250848   0.034267     9900 0.13939
# Sex                        0.196187  -0.012880   0.408202     9568 0.06909 .
# MaleAge                    0.051065  -0.050723   0.159467     9900 0.33838
# FemaleAge                  0.074601  -0.043880   0.182065     9900 0.19152
# HatchBroodSize            -0.032529  -0.162880   0.094378     9900 0.62424
# poly(HatchBroodSize, 2)2  -7.080357 -14.062246   0.002806     9900 0.04747 *
# poly(HatchDateCode, 2)1    3.926141  -3.043499  11.333676     9618 0.28566
# poly(HatchDateCode, 2)2   -9.417907 -16.597436  -2.312442     9900 0.00889 **
# Fostered                   0.237636  -0.031820   0.510155     9900 0.08626 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 1540.307
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID   0.05319 0.0001385   0.2224     9289
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID    0.0261 0.0001417    0.106    10274
#
#                ~RearBrood
#
#           post.mean l-95% CI u-95% CI eff.samp
# RearBrood    0.8997   0.3367    1.524     9459
#
#                ~Year
#
#      post.mean l-95% CI u-95% CI eff.samp
# Year     7.002   0.6581    18.05     1380
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location   0.09897 0.0001497   0.4361    10194
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units     1.507   0.8901     2.16     9900
#
#  Location effects: Longevity ~ z_AvgMeerkatRateChick + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                          post.mean  l-95% CI  u-95% CI eff.samp    pMCMC
# (Intercept)               -4.47124  -6.65175  -2.42627     6287 0.000202 ***
# z_AvgMeerkatRateChick      0.03622  -0.15815   0.23276     9900 0.695960
# Sex                       -0.03017  -0.34583   0.26703    10279 0.846465
# MaleAge                    0.07693  -0.06971   0.23671     9900 0.326667
# FemaleAge                 -0.01251  -0.16571   0.14173     9900 0.895960
# HatchBroodSize             0.07473  -0.11518   0.27905     9900 0.450303
# poly(HatchBroodSize, 2)2  -7.47785 -16.91331   2.56104     9900 0.125051
# poly(HatchDateCode, 2)1   -8.88716 -19.00476   0.72354     9255 0.079394 .
# poly(HatchDateCode, 2)2  -14.19762 -23.44515  -5.30406     9607 0.002424 **
# Fostered                   0.03748  -0.33491   0.39615     9900 0.831515
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 1508.01
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID   0.08966 0.0001535   0.3412     8431
#
#                ~FemaleID
#
#          post.mean l-95% CI u-95% CI eff.samp
# FemaleID    0.0251 0.000187   0.1021     9900
#
#                ~RearBrood
#
#           post.mean l-95% CI u-95% CI eff.samp
# RearBrood    0.7688   0.1381    1.423     7849
#
#                ~Year
#
#      post.mean l-95% CI u-95% CI eff.samp
# Year     6.318   0.5873    16.63     4577
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location    0.1253 0.0001884   0.5666     9900
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units     1.628   0.9453    2.322     9321
#
#  Location effects: Longevity ~ z_MeerkatRateChick7 + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                           post.mean   l-95% CI   u-95% CI eff.samp    pMCMC
# (Intercept)               -4.593352  -6.750251  -2.644081     8376 0.000808 ***
# z_MeerkatRateChick7        0.115235  -0.085669   0.295399     9900 0.228283
# Sex                       -0.023110  -0.342110   0.283640     9900 0.884848
# MaleAge                    0.085006  -0.077076   0.236576     9595 0.279596
# FemaleAge                 -0.029190  -0.186445   0.130184     9900 0.726263
# HatchBroodSize             0.137545  -0.060859   0.332396     9900 0.167071
# poly(HatchBroodSize, 2)2  -7.836029 -16.935485   1.089843     9900 0.081010 .
# poly(HatchDateCode, 2)1   -9.166992 -18.790843  -0.079351     9900 0.053939 .
# poly(HatchDateCode, 2)2  -13.841781 -22.919951  -5.059918    10912 0.002020 **
# Fostered                  -0.004298  -0.372687   0.346602     9900 0.981414
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 1554.153
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID   0.04212 0.0001369   0.1741     9513
#
#                ~FemaleID
#
#          post.mean l-95% CI u-95% CI eff.samp
# FemaleID   0.02367 0.000161  0.09562     9900
#
#                ~RearBrood
#
#           post.mean  l-95% CI u-95% CI eff.samp
# RearBrood    0.6107 0.0003315    1.091     7092
#
#                ~Year
#
#      post.mean l-95% CI u-95% CI eff.samp
# Year     6.334   0.6718    17.01     6722
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location    0.1043 0.0001506   0.4715     9900
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units     1.631   0.9797    2.303     8609
#
#  Location effects: Longevity ~ z_MeerkatRateChick11 + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                          post.mean  l-95% CI  u-95% CI eff.samp    pMCMC
# (Intercept)               -4.33846  -6.29939  -2.38397     9200 0.000202 ***
# z_MeerkatRateChick11       0.06650  -0.09465   0.23755    10222 0.421818
# Sex                       -0.05051  -0.36217   0.25406    10204 0.747677
# MaleAge                    0.08120  -0.06396   0.23154     9900 0.272121
# FemaleAge                 -0.00955  -0.15657   0.13185     9900 0.903434
# HatchBroodSize             0.06747  -0.10573   0.26311     9900 0.482424
# poly(HatchBroodSize, 2)2  -9.21476 -19.06548  -0.28189     9900 0.050303 .
# poly(HatchDateCode, 2)1   -5.00404 -14.27017   3.77689     9900 0.264040
# poly(HatchDateCode, 2)2  -13.12181 -21.69669  -5.19178     9900 0.001212 **
# Fostered                   0.02140  -0.32499   0.35323     9900 0.917576
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# ## First Breed Age

# %%
Vect <- c(6,12,18,24,30,36)
for(i in 1:length(Vect)){
load(paste("../FinalResults/IndivModel_",Vect[i],".rda", sep=""))
print(summary(Model))
}
# Out:
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 987.1251
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID  0.003295 0.0001684  0.00985     9498
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID  0.003344 0.0001709  0.01008     9451
#
#                ~RearBrood
#
#           post.mean  l-95% CI u-95% CI eff.samp
# RearBrood  0.003144 0.0002088 0.009158    10486
#
#                ~Year
#
#      post.mean  l-95% CI u-95% CI eff.samp
# Year  0.004576 0.0001842  0.01495     9900
#
#                ~Location
#
#          post.mean l-95% CI u-95% CI eff.samp
# Location  0.005753 0.000194  0.01933     9900
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units   0.01182 0.003428  0.02296     9900
#
#  Location effects: FirstBreedAge ~ z_AvgFeedRateChick + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                           post.mean   l-95% CI   u-95% CI eff.samp pMCMC
# (Intercept)               0.0117459 -0.4524452  0.4478202     9640 0.964
# z_AvgFeedRateChick        0.0012944 -0.1179749  0.1106547     9578 0.984
# Sex                       0.0572110 -0.1308598  0.2370110     9530 0.544
# MaleAge                  -0.0054532 -0.0842254  0.0721434     9597 0.893
# FemaleAge                 0.0030475 -0.0758109  0.0844767     9833 0.943
# HatchBroodSize           -0.0008677 -0.1035403  0.1031560     9202 0.990
# poly(HatchBroodSize, 2)2 -0.4582190 -2.4434655  1.5427033     9266 0.655
# poly(HatchDateCode, 2)1   0.3388165 -1.6360459  2.2817235     9557 0.737
# poly(HatchDateCode, 2)2   0.0288021 -1.9776120  1.9894401     9900 0.970
# Fostered                  0.0013288 -0.1881543  0.1877240     9497 0.989
#
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 926.3316
#
#  G-structure:  ~MaleID
#
#        post.mean l-95% CI u-95% CI eff.samp
# MaleID  0.003459 0.000153  0.01032    10105
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID  0.003412 0.0001861  0.01029     9199
#
#                ~RearBrood
#
#           post.mean  l-95% CI u-95% CI eff.samp
# RearBrood  0.003277 0.0001986 0.009709    10186
#
#                ~Year
#
#      post.mean l-95% CI u-95% CI eff.samp
# Year  0.004728 0.000191  0.01547     9900
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location  0.006033 0.0001597  0.02041     9900
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units   0.01221 0.003278  0.02335     9900
#
#  Location effects: FirstBreedAge ~ z_FeedRateChick7 + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                           post.mean   l-95% CI   u-95% CI eff.samp pMCMC
# (Intercept)               0.0051346 -0.4545763  0.4801150     9900 0.969
# z_FeedRateChick7          0.0100197 -0.1111310  0.1294834     9900 0.876
# Sex                       0.0593192 -0.1299166  0.2460988     9375 0.538
# MaleAge                  -0.0055633 -0.0832870  0.0760305     9230 0.895
# FemaleAge                 0.0032339 -0.0792927  0.0864608     9587 0.927
# HatchBroodSize            0.0008895 -0.1060237  0.1135695     9900 0.991
# poly(HatchBroodSize, 2)2 -0.4870075 -2.5751351  1.4228372     9900 0.646
# poly(HatchDateCode, 2)1   0.3044869 -1.5945343  2.3624903     9900 0.761
# poly(HatchDateCode, 2)2   0.0904848 -1.8717533  2.0913654     9900 0.919
# Fostered                  0.0030842 -0.1917313  0.1977944    10570 0.969
#
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 905.4842
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID  0.003558 0.0001722  0.01063     9900
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID   0.00349 0.0002005  0.01053     9900
#
#                ~RearBrood
#
#           post.mean  l-95% CI u-95% CI eff.samp
# RearBrood   0.00338 0.0001742  0.01022    10223
#
#                ~Year
#
#      post.mean  l-95% CI u-95% CI eff.samp
# Year  0.004741 0.0001501  0.01551     9558
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location   0.00605 0.0001662  0.02132     9900
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units   0.01239 0.003339  0.02394     9900
#
#  Location effects: FirstBreedAge ~ z_FeedRateChick11 + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                           post.mean   l-95% CI   u-95% CI eff.samp pMCMC
# (Intercept)               0.0108185 -0.4723940  0.4939472     9603 0.950
# z_FeedRateChick11         0.0013272 -0.1153234  0.1143082     9210 0.967
# Sex                       0.0629669 -0.1258824  0.2523457     9335 0.531
# MaleAge                  -0.0052505 -0.0858056  0.0795980     9188 0.899
# FemaleAge                 0.0009484 -0.0859717  0.0853910     9900 0.991
# HatchBroodSize            0.0004761 -0.1027341  0.1105513     9482 0.989
# poly(HatchBroodSize, 2)2 -0.4118142 -2.4335429  1.5485266     9447 0.695
# poly(HatchDateCode, 2)1   0.2835040 -1.6929436  2.2741555     9482 0.785
# poly(HatchDateCode, 2)2  -0.0325946 -2.0713173  1.9549256     9559 0.982
# Fostered                 -0.0078077 -0.2207761  0.1836851     9416 0.939
#
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 682.6066
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID  0.004438 0.0001397  0.01379     9900
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID  0.004378 0.0001871  0.01399     9900
#
#                ~RearBrood
#
#           post.mean  l-95% CI u-95% CI eff.samp
# RearBrood  0.004168 0.0001616   0.0127     9900
#
#                ~Year
#
#      post.mean  l-95% CI u-95% CI eff.samp
# Year  0.008314 0.0001303  0.02947     9900
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location  0.009861 0.0001444  0.03611     9716
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units    0.0148 0.003513  0.02956     9900
#
#  Location effects: FirstBreedAge ~ z_AvgMeerkatRateChick + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                           post.mean   l-95% CI   u-95% CI eff.samp pMCMC
# (Intercept)               1.192e-01 -4.083e-01  6.607e-01    10522 0.642
# z_AvgMeerkatRateChick    -1.629e-02 -1.363e-01  1.059e-01     9900 0.805
# Sex                       7.095e-02 -1.526e-01  2.932e-01     9392 0.539
# MaleAge                  -1.061e-02 -9.627e-02  7.605e-02     9948 0.809
# FemaleAge                -3.966e-05 -8.578e-02  8.957e-02     9900 0.988
# HatchBroodSize           -2.252e-02 -1.469e-01  1.037e-01    10368 0.720
# poly(HatchBroodSize, 2)2 -2.176e-01 -2.189e+00  1.738e+00     9541 0.849
# poly(HatchDateCode, 2)1   7.310e-02 -1.995e+00  2.077e+00     9160 0.943
# poly(HatchDateCode, 2)2  -1.006e-03 -2.009e+00  1.980e+00     9900 0.980
# Fostered                 -1.837e-03 -2.296e-01  2.297e-01     9900 0.982
#
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 665.3596
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID  0.004354 0.0001767  0.01373     9900
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID   0.00445 0.0001252  0.01424     9900
#
#                ~RearBrood
#
#           post.mean  l-95% CI u-95% CI eff.samp
# RearBrood  0.004225 0.0001581   0.0129     9900
#
#                ~Year
#
#      post.mean  l-95% CI u-95% CI eff.samp
# Year  0.008831 0.0001491  0.03145     9096
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location    0.0104 0.0001811  0.03879     9977
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units   0.01519 0.003779  0.03106     9749
#
#  Location effects: FirstBreedAge ~ z_MeerkatRateChick7 + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                          post.mean  l-95% CI  u-95% CI eff.samp pMCMC
# (Intercept)               0.149965 -0.406280  0.688188     9477 0.597
# z_MeerkatRateChick7      -0.013189 -0.135825  0.104106     9900 0.848
# Sex                       0.063867 -0.163215  0.286111     9900 0.579
# MaleAge                  -0.011738 -0.095848  0.076981     9900 0.784
# FemaleAge                -0.000252 -0.093605  0.087254     9900 0.992
# HatchBroodSize           -0.027655 -0.158910  0.098966     9585 0.676
# poly(HatchBroodSize, 2)2 -0.210367 -2.216759  1.641218     9900 0.848
# poly(HatchDateCode, 2)1   0.200865 -1.827864  2.160488     9900 0.857
# poly(HatchDateCode, 2)2   0.112350 -1.932420  2.157052     9900 0.909
# Fostered                 -0.002428 -0.243071  0.230576     9614 0.976
#
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 679.2686
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID  0.004338 0.0001726  0.01378     9493
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID  0.004327 0.0001439   0.0133     9900
#
#                ~RearBrood
#
#           post.mean  l-95% CI u-95% CI eff.samp
# RearBrood    0.0042 0.0001469  0.01315     9551
#
#                ~Year
#
#      post.mean  l-95% CI u-95% CI eff.samp
# Year  0.008343 0.0001608  0.02889     9900
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location  0.009842 0.0001502  0.03757     9900
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units   0.01487 0.003796  0.02994     9583
#
#  Location effects: FirstBreedAge ~ z_MeerkatRateChick11 + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                          post.mean  l-95% CI  u-95% CI eff.samp pMCMC
# (Intercept)               0.136328 -0.393778  0.660658     9760 0.616
# z_MeerkatRateChick11     -0.019196 -0.141208  0.099631     9820 0.772
# Sex                       0.066156 -0.159615  0.290072    11963 0.569
# MaleAge                  -0.010420 -0.093155  0.074317     9900 0.812
# FemaleAge                -0.004860 -0.093747  0.083471     9813 0.927
# HatchBroodSize           -0.022453 -0.149708  0.098255     9900 0.724
# poly(HatchBroodSize, 2)2 -0.216046 -2.116052  1.807469     9443 0.850
# poly(HatchDateCode, 2)1  -0.007166 -2.112968  2.028458     9499 0.993
# poly(HatchDateCode, 2)2  -0.063464 -2.057649  1.913256     9493 0.964
# Fostered                 -0.013550 -0.254138  0.215258     9900 0.913

# %% [markdown]
# ## Lifetime Recruits

# %%
Vect <- c(4,10,16,22,28,34)
for(i in 1:length(Vect)){
load(paste("../FinalResults/IndivModel_",Vect[i],".rda", sep=""))
print(summary(Model))
}
# Out:
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 1758.759
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID     0.984 0.0002891    1.948     6522
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID     0.206 0.0001932   0.8556     6419
#
#                ~RearBrood
#
#           post.mean  l-95% CI u-95% CI eff.samp
# RearBrood     1.339 0.0001844    2.825     3031
#
#                ~Year
#
#      post.mean l-95% CI u-95% CI eff.samp
# Year     3.679   0.9223    7.861     9900
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location    0.1356 0.0001762   0.6005     9900
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units     7.738    5.673    9.848     6266
#
#  Location effects: Recruits ~ z_AvgFeedRateChick + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                           post.mean   l-95% CI   u-95% CI eff.samp    pMCMC
# (Intercept)               -5.934520  -7.701819  -4.167173     9900  < 1e-04 ***
# z_AvgFeedRateChick         0.064112  -0.226091   0.352980     9900 0.666667
# Sex                        0.089901  -0.355162   0.543944     9900 0.693535
# MaleAge                    0.109656  -0.101891   0.331412    10360 0.322222
# FemaleAge                 -0.003022  -0.230490   0.231569     9900 0.976162
# HatchBroodSize             0.056804  -0.214024   0.325375     9900 0.691111
# poly(HatchBroodSize, 2)2  -9.787075 -24.829272   6.081947     9900 0.212121
# poly(HatchDateCode, 2)1   -9.284028 -26.239828   5.773177     9876 0.251111
# poly(HatchDateCode, 2)2  -26.923086 -43.285216 -11.857526     9900 0.000404 ***
# Fostered                   0.134628  -0.394333   0.672650     9900 0.625657
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 1661.51
#
#  G-structure:  ~MaleID
#
#        post.mean l-95% CI u-95% CI eff.samp
# MaleID    0.9381 0.000256    1.876     7239
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID    0.1634 0.0001739   0.7308     7125
#
#                ~RearBrood
#
#           post.mean  l-95% CI u-95% CI eff.samp
# RearBrood     1.057 0.0002456    2.577     2562
#
#                ~Year
#
#      post.mean l-95% CI u-95% CI eff.samp
# Year     4.006    1.035    8.481     9900
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location    0.1528 0.0001861   0.6814     9900
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units     8.328    6.017    10.53     5850
#
#  Location effects: Recruits ~ z_FeedRateChick7 + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                           post.mean   l-95% CI   u-95% CI eff.samp   pMCMC
# (Intercept)              -6.200e+00 -8.000e+00 -4.393e+00    10592 < 1e-04 ***
# z_FeedRateChick7          1.358e-01 -1.512e-01  4.246e-01     9900 0.34525
# Sex                       1.261e-01 -3.222e-01  6.077e-01     9900 0.59313
# MaleAge                   1.094e-01 -1.089e-01  3.320e-01    10548 0.32828
# FemaleAge                -5.701e-04 -2.218e-01  2.390e-01     9900 0.99758
# HatchBroodSize            1.007e-01 -1.951e-01  3.831e-01    10624 0.49394
# poly(HatchBroodSize, 2)2 -1.176e+01 -2.743e+01  4.277e+00     9900 0.13495
# poly(HatchDateCode, 2)1  -1.092e+01 -2.654e+01  5.325e+00     9900 0.17818
# poly(HatchDateCode, 2)2  -2.352e+01 -3.881e+01 -7.494e+00     9900 0.00202 **
# Fostered                  2.003e-01 -3.510e-01  7.483e-01     9900 0.47677
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 1621.351
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID     1.079 0.0001927    2.085     8190
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID    0.1857 0.0001787    0.797     7312
#
#                ~RearBrood
#
#           post.mean  l-95% CI u-95% CI eff.samp
# RearBrood    0.9549 0.0002535    2.382     3014
#
#                ~Year
#
#      post.mean l-95% CI u-95% CI eff.samp
# Year     3.436   0.9153    7.254    10675
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location    0.1446 0.0001287   0.6702     9399
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units     7.745    5.599    9.931     6046
#
#  Location effects: Recruits ~ z_FeedRateChick11 + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                           post.mean   l-95% CI   u-95% CI eff.samp   pMCMC
# (Intercept)              -5.497e+00 -7.262e+00 -3.729e+00     9900 < 1e-04 ***
# z_FeedRateChick11        -7.682e-02 -3.633e-01  2.221e-01     9900 0.61576
# Sex                      -1.447e-02 -4.490e-01  4.459e-01     9900 0.94384
# MaleAge                   1.094e-01 -1.156e-01  3.263e-01     9900 0.32889
# FemaleAge                 9.857e-04 -2.374e-01  2.258e-01     9900 0.99152
# HatchBroodSize           -1.779e-03 -2.810e-01  2.660e-01     9900 0.98788
# poly(HatchBroodSize, 2)2 -7.922e+00 -2.255e+01  6.963e+00     9900 0.28566
# poly(HatchDateCode, 2)1  -4.894e+00 -1.944e+01  1.019e+01     9900 0.52889
# poly(HatchDateCode, 2)2  -2.128e+01 -3.571e+01 -5.857e+00    10229 0.00283 **
# Fostered                  7.421e-03 -5.536e-01  5.725e-01     9900 0.97818
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 1106.53
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID    0.1113 0.0001671   0.4927     9062
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID   0.05597 0.0001548   0.2474     9900
#
#                ~RearBrood
#
#           post.mean  l-95% CI u-95% CI eff.samp
# RearBrood      1.84 0.0002467    3.427     5981
#
#                ~Year
#
#      post.mean l-95% CI u-95% CI eff.samp
# Year     1.732    0.183    4.615     9900
#
#                ~Location
#
#          post.mean l-95% CI u-95% CI eff.samp
# Location    0.1543 0.000113   0.6227     9900
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units     5.901    3.861    8.069     9163
#
#  Location effects: Recruits ~ z_AvgMeerkatRateChick + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                          post.mean  l-95% CI  u-95% CI eff.samp  pMCMC
# (Intercept)               -6.54673  -8.38660  -4.73112     9900 <1e-04 ***
# z_AvgMeerkatRateChick      0.01758  -0.30126   0.31943     9900 0.9089
# Sex                       -0.03455  -0.55663   0.45656     9900 0.8933
# MaleAge                    0.14097  -0.08139   0.36478    10269 0.2143
# FemaleAge                  0.07524  -0.14906   0.30083     9900 0.5038
# HatchBroodSize             0.28082  -0.02519   0.58268     9900 0.0667 .
# poly(HatchBroodSize, 2)2  -8.36922 -23.50794   6.31521     9900 0.2683
# poly(HatchDateCode, 2)1  -10.64145 -24.91404   3.53680     9900 0.1418
# poly(HatchDateCode, 2)2  -10.63162 -24.08454   2.77341    10420 0.1139
# Fostered                   0.05341  -0.52030   0.63072     9373 0.8622
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 1075.957
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID    0.1115 0.0002156   0.5045     8796
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID   0.05468 0.0001754   0.2435     9900
#
#                ~RearBrood
#
#           post.mean  l-95% CI u-95% CI eff.samp
# RearBrood     1.645 0.0002277    3.292     5522
#
#                ~Year
#
#      post.mean l-95% CI u-95% CI eff.samp
# Year     1.724    0.128    4.586     9900
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location     0.162 0.0001775   0.6703     7758
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units     6.429    4.208    8.764     7930
#
#  Location effects: Recruits ~ z_MeerkatRateChick7 + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                          post.mean  l-95% CI  u-95% CI eff.samp  pMCMC
# (Intercept)               -6.69076  -8.65273  -4.94691     9900 <1e-04 ***
# z_MeerkatRateChick7        0.10454  -0.19295   0.39256    10337 0.4780
# Sex                       -0.09013  -0.64462   0.41680     9900 0.7382
# MaleAge                    0.18312  -0.04202   0.40627     9900 0.1097
# FemaleAge                  0.07363  -0.15491   0.30366    10689 0.5226
# HatchBroodSize             0.28797  -0.01307   0.59771     9900 0.0628 .
# poly(HatchBroodSize, 2)2  -7.57233 -20.64387   7.19571     9900 0.2982
# poly(HatchDateCode, 2)1  -10.55300 -24.75232   3.84269     9900 0.1461
# poly(HatchDateCode, 2)2  -11.97166 -25.56614   2.18919     8903 0.0867 .
# Fostered                  -0.03206  -0.60690   0.56544     9900 0.8982
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#  Iterations = 100001:9999001
#  Thinning interval  = 1000
#  Sample size  = 9900
#
#  DIC: 1112.288
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID    0.1233 0.0001839   0.5257     8491
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID   0.05795 0.0001628    0.254     9900
#
#                ~RearBrood
#
#           post.mean  l-95% CI u-95% CI eff.samp
# RearBrood     1.622 0.0003124    3.121     5611
#
#                ~Year
#
#      post.mean l-95% CI u-95% CI eff.samp
# Year     1.672    0.163    4.374     9900
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location    0.1452 0.0001815   0.6295     9900
#
#  R-structure:  ~units
#
#       post.mean l-95% CI u-95% CI eff.samp
# units     5.669    3.686    7.702     6857
#
#  Location effects: Recruits ~ z_MeerkatRateChick11 + Sex + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                          post.mean  l-95% CI  u-95% CI eff.samp  pMCMC
# (Intercept)               -6.39549  -8.27705  -4.67693     9900 <1e-04 ***
# z_MeerkatRateChick11       0.04455  -0.22836   0.32333     9900 0.7455
# Sex                       -0.06252  -0.57298   0.43481     9900 0.8152
# MaleAge                    0.14983  -0.06755   0.36316    10987 0.1697
# FemaleAge                  0.06331  -0.16249   0.27993     9900 0.5701
# HatchBroodSize             0.28168  -0.01195   0.58722     9900 0.0644 .
# poly(HatchBroodSize, 2)2 -10.35195 -25.31296   3.93948    10524 0.1572
# poly(HatchDateCode, 2)1   -7.04328 -20.31416   7.16723     9900 0.3051
# poly(HatchDateCode, 2)2  -10.89691 -24.01978   1.43147     9900 0.0899 .
# Fostered                   0.03072  -0.51890   0.58120    10229 0.9149
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
