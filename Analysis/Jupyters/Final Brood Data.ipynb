# %% [markdown]
# # Brood Final Analysis

# %%
library(MCMCglmm)
# Out:
# Loading required package: Matrix
#
# Loading required package: coda
#
# Loading required package: ape

# %% [markdown]
# ## Fledge Brood Size

# %%
Vect <- c(2,4,6,8,10,12)
for(i in 1:length(Vect)){
load(paste("../FinalResults/MCMCBroodOut_",Vect[i],".rda", sep=""))
print(summary(Model))
}
# Out:
#  Iterations = 100001:49995001
#  Thinning interval  = 5000
#  Sample size  = 9980
#
#  DIC: 2684.446
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID  0.001786 4.206e-11 0.006769     9980
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID  0.001865 4.683e-12 0.007109     9820
#
#                ~BroodYear
#
#           post.mean l-95% CI u-95% CI eff.samp
# BroodYear    0.1631  0.04527   0.3487     6178
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location   0.01017 1.217e-10    0.034     9156
#
#  R-structure:  ~units
#
#       post.mean  l-95% CI u-95% CI eff.samp
# units  0.002225 0.0001768 0.005945     9980
#
#  Location effects: FledgeBroodSize ~ AvgFeedRate + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                          post.mean  l-95% CI  u-95% CI eff.samp    pMCMC
# (Intercept)              -0.880597 -1.236512 -0.526135     9371  < 1e-04 ***
# AvgFeedRate               0.036420  0.030495  0.042961     9362  < 1e-04 ***
# MaleAge                   0.028638 -0.008159  0.068078     9380 0.141283
# FemaleAge                 0.043273 -0.001060  0.085451     9980 0.053307 .
# HatchBroodSize            0.129818  0.070389  0.192977     9196  < 1e-04 ***
# poly(HatchBroodSize, 2)2 -2.315703 -4.245529 -0.556409     9219 0.011623 *
# poly(HatchDateCode, 2)1   1.704007 -0.008225  3.453971     9402 0.056914 .
# poly(HatchDateCode, 2)2  -2.983367 -4.744484 -1.379965     9515 0.000401 ***
# Fostered                  0.012087 -0.108355  0.138163     9980 0.851303
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Iterations = 100001:49995001
#  Thinning interval  = 5000
#  Sample size  = 9980
#
#  DIC: 2607.124
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID  0.001707 2.121e-11 0.006464     9465
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID  0.001841 2.651e-12 0.006993     9146
#
#                ~BroodYear
#
#           post.mean l-95% CI u-95% CI eff.samp
# BroodYear    0.1662  0.04052   0.3537     5408
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location  0.005245 1.996e-10  0.02092     9729
#
#  R-structure:  ~units
#
#       post.mean  l-95% CI u-95% CI eff.samp
# units  0.002386 0.0001991 0.006601     9980
#
#  Location effects: FledgeBroodSize ~ FeedRate7 + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                          post.mean l-95% CI u-95% CI eff.samp    pMCMC
# (Intercept)               -0.81998 -1.16685 -0.44234     9521 0.000200 ***
# FeedRate7                  0.02988  0.02353  0.03578     9557  < 1e-04 ***
# MaleAge                    0.02779 -0.01041  0.06576     9980 0.157715
# FemaleAge                  0.03253 -0.01011  0.07516     9571 0.132866
# HatchBroodSize             0.17096  0.11089  0.23028     9346  < 1e-04 ***
# poly(HatchBroodSize, 2)2  -2.29140 -4.08215 -0.43903     9267 0.010621 *
# poly(HatchDateCode, 2)1    1.77266 -0.02483  3.46615     9318 0.046293 *
# poly(HatchDateCode, 2)2   -2.99563 -4.73108 -1.28604     9506 0.000601 ***
# Fostered                   0.03722 -0.09101  0.16801     9388 0.567535
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Iterations = 100001:49995001
#  Thinning interval  = 5000
#  Sample size  = 9980
#
#  DIC: 2347.153
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID  0.001581 3.619e-10 0.006168     9980
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID  0.001513 4.391e-12 0.005769     9437
#
#                ~BroodYear
#
#           post.mean l-95% CI u-95% CI eff.samp
# BroodYear     0.177  0.04216   0.3817     4997
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location  0.006252 4.545e-12  0.02268     9133
#
#  R-structure:  ~units
#
#       post.mean  l-95% CI u-95% CI eff.samp
# units  0.002131 0.0001839  0.00568     9980
#
#  Location effects: FledgeBroodSize ~ FeedRate11 + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                          post.mean  l-95% CI  u-95% CI eff.samp   pMCMC
# (Intercept)              -0.581173 -0.952141 -0.224520     9229 0.00200 **
# FeedRate11                0.020354  0.015049  0.025769     9980 < 1e-04 ***
# MaleAge                   0.020471 -0.017817  0.061274     9631 0.30902
# FemaleAge                 0.034489 -0.009285  0.080265     9617 0.12826
# HatchBroodSize            0.156818  0.094612  0.219592     9102 < 1e-04 ***
# poly(HatchBroodSize, 2)2 -2.227297 -3.973112 -0.574144     8983 0.00982 **
# poly(HatchDateCode, 2)1   1.108740 -0.543452  2.710492     9636 0.18818
# poly(HatchDateCode, 2)2  -2.518216 -4.107131 -0.962315     9657 0.00180 **
# Fostered                  0.021142 -0.104753  0.152274     9980 0.75010
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Iterations = 100001:49995001
#  Thinning interval  = 5000
#  Sample size  = 9980
#
#  DIC: 1746.481
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID  0.004475 1.007e-10  0.01722     9356
#
#                ~FemaleID
#
#          post.mean l-95% CI u-95% CI eff.samp
# FemaleID  0.008363 1.13e-09   0.0314     8957
#
#                ~BroodYear
#
#           post.mean l-95% CI u-95% CI eff.samp
# BroodYear    0.4485  0.07379    1.067     5309
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location   0.02114 2.665e-10  0.07858     9671
#
#  R-structure:  ~units
#
#       post.mean  l-95% CI u-95% CI eff.samp
# units  0.005289 0.0001677  0.01741     9980
#
#  Location effects: FledgeBroodSize ~ AvgMeerkatRate + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                           post.mean   l-95% CI   u-95% CI eff.samp    pMCMC
# (Intercept)               -1.998279  -2.632884  -1.373448     7313  < 1e-04 ***
# AvgMeerkatRate             0.007391   0.003222   0.011334     9340 0.000401 ***
# MaleAge                    0.039681  -0.012414   0.096625     9980 0.163527
# FemaleAge                  0.027778  -0.028504   0.084004     9852 0.331062
# HatchBroodSize             0.409332   0.296625   0.516319     6072  < 1e-04 ***
# poly(HatchBroodSize, 2)2  -6.810976  -9.906130  -3.930856     6414  < 1e-04 ***
# poly(HatchDateCode, 2)1   -0.263180  -2.677263   2.128901     8799 0.839279
# poly(HatchDateCode, 2)2   -8.323093 -10.704023  -5.971483     9434  < 1e-04 ***
# Fostered                  -0.043344  -0.201437   0.125642     9446 0.608818
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Iterations = 100001:49995001
#  Thinning interval  = 5000
#  Sample size  = 9980
#
#  DIC: 1667.293
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID  0.003957 6.555e-14  0.01532     9980
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID  0.006377 6.449e-10  0.02431     8861
#
#                ~BroodYear
#
#           post.mean l-95% CI u-95% CI eff.samp
# BroodYear    0.4328  0.06838    1.045     5630
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location   0.01846 4.374e-09  0.06935     9375
#
#  R-structure:  ~units
#
#       post.mean  l-95% CI u-95% CI eff.samp
# units  0.004967 0.0002084  0.01593     9645
#
#  Location effects: FledgeBroodSize ~ MeerkatRate7 + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                           post.mean   l-95% CI   u-95% CI eff.samp    pMCMC
# (Intercept)               -1.332136  -1.917191  -0.737159     9085 0.000401 ***
# MeerkatRate7               0.006192   0.002780   0.009667     9980  < 1e-04 ***
# MaleAge                    0.038324  -0.015464   0.094305     9625 0.180762
# FemaleAge                  0.019723  -0.035488   0.080937     9980 0.500601
# HatchBroodSize             0.250958   0.165434   0.342288     9304  < 1e-04 ***
# poly(HatchBroodSize, 2)2  -3.010132  -5.169213  -0.775480     9493 0.004810 **
# poly(HatchDateCode, 2)1   -0.153509  -2.421673   2.141461     8606 0.889780
# poly(HatchDateCode, 2)2   -8.128459 -10.470319  -5.888721     9541  < 1e-04 ***
# Fostered                  -0.013314  -0.181473   0.145428     9609 0.867936
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Iterations = 100001:49995001
#  Thinning interval  = 5000
#  Sample size  = 9980
#
#  DIC: 1735.04
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID  0.003765 1.198e-09  0.01421     9531
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID  0.004889 4.821e-11  0.01881     9456
#
#                ~BroodYear
#
#           post.mean l-95% CI u-95% CI eff.samp
# BroodYear    0.4542  0.07832    1.106     5025
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location   0.01109 1.295e-10  0.04748     9505
#
#  R-structure:  ~units
#
#       post.mean  l-95% CI u-95% CI eff.samp
# units  0.004927 0.0001796  0.01589     9980
#
#  Location effects: FledgeBroodSize ~ MeerkatRate11 + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                           post.mean   l-95% CI   u-95% CI eff.samp  pMCMC
# (Intercept)              -1.7033898 -2.3291051 -1.1305653     8192 <1e-04 ***
# MeerkatRate11             0.0031521 -0.0001673  0.0063319     9549 0.0545 .
# MaleAge                   0.0469369 -0.0092326  0.0997310     9980 0.0904 .
# FemaleAge                 0.0071634 -0.0496748  0.0620818     9398 0.7836
# HatchBroodSize            0.3956418  0.2929931  0.4996090     6736 <1e-04 ***
# poly(HatchBroodSize, 2)2 -5.6206657 -8.4677678 -2.7479228     7120 <1e-04 ***
# poly(HatchDateCode, 2)1  -0.5604275 -2.7813832  1.8248608     9429 0.6285
# poly(HatchDateCode, 2)2  -7.0139268 -9.2332464 -4.6840858     9980 <1e-04 ***
# Fostered                 -0.0313413 -0.1945224  0.1270806     9980 0.7012
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %% [markdown]
# ## Number of Recruits

# %%
Vect <- c(1,3,5,7,9,11)
for(i in 1:length(Vect)){
load(paste("../FinalResults/MCMCBroodOut_",Vect[i],".rda", sep=""))
print(summary(Model))
}
# Out:
#  Iterations = 100001:49995001
#  Thinning interval  = 5000
#  Sample size  = 9980
#
#  DIC: 1568.3
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID   0.06108 2.331e-08   0.1537     5209
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID   0.01687 1.667e-11  0.06365     8088
#
#                ~BroodYear
#
#           post.mean l-95% CI u-95% CI eff.samp
# BroodYear    0.9759   0.2449    2.106     5329
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location   0.02841 1.803e-10   0.1121     8297
#
#  R-structure:  ~units
#
#       post.mean  l-95% CI u-95% CI eff.samp
# units   0.01422 0.0001522  0.05406     8545
#
#  Location effects: Recruits ~ AvgFeedRate + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                          post.mean  l-95% CI  u-95% CI eff.samp    pMCMC
# (Intercept)               -2.19862  -2.96381  -1.40001     9222  < 1e-04 ***
# AvgFeedRate                0.02483   0.01283   0.03658     9113  < 1e-04 ***
# MaleAge                    0.04396  -0.03931   0.12681     9536 0.295591
# FemaleAge                  0.03316  -0.05492   0.11783     9661 0.446894
# HatchBroodSize             0.20005   0.08158   0.31884     8001 0.000401 ***
# poly(HatchBroodSize, 2)2  -4.19630  -7.73865  -0.77634     8002 0.013026 *
# poly(HatchDateCode, 2)1    1.34069  -2.09803   4.70059     8916 0.444088
# poly(HatchDateCode, 2)2   -7.35062 -10.73649  -4.06585     9040  < 1e-04 ***
# Fostered                  -0.17076  -0.42309   0.06443     8915 0.171343
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Iterations = 100001:49995001
#  Thinning interval  = 5000
#  Sample size  = 9980
#
#  DIC: 1474.457
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID   0.05029 1.189e-10   0.1417     5923
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID   0.01522 1.777e-10  0.05766     8263
#
#                ~BroodYear
#
#           post.mean l-95% CI u-95% CI eff.samp
# BroodYear    0.9519   0.2022    2.034     5656
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location   0.03383 8.104e-12   0.1332     8976
#
#  R-structure:  ~units
#
#       post.mean  l-95% CI u-95% CI eff.samp
# units   0.01364 0.0001867   0.0511     9980
#
#  Location effects: Recruits ~ FeedRate7 + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                           post.mean   l-95% CI   u-95% CI eff.samp  pMCMC
# (Intercept)               -2.309657  -3.087516  -1.550749     9256 <1e-04 ***
# FeedRate7                  0.027084   0.014864   0.039124     9355 <1e-04 ***
# MaleAge                    0.036556  -0.051246   0.115173     9220 0.3749
# FemaleAge                  0.006853  -0.082532   0.093945     9676 0.8766
# HatchBroodSize             0.247647   0.123206   0.370194     8377 <1e-04 ***
# poly(HatchBroodSize, 2)2  -3.982435  -7.642007  -0.491632     8580 0.0236 *
# poly(HatchDateCode, 2)1    1.335995  -2.097228   4.853524     8620 0.4619
# poly(HatchDateCode, 2)2   -6.961194 -10.441600  -3.434100     8954 <1e-04 ***
# Fostered                  -0.157945  -0.400116   0.091531     9061 0.2018
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Iterations = 100001:49995001
#  Thinning interval  = 5000
#  Sample size  = 9980
#
#  DIC: 1395.241
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID   0.04274 2.022e-10   0.1263     6420
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID   0.01968 2.003e-11  0.07187     8068
#
#                ~BroodYear
#
#           post.mean l-95% CI u-95% CI eff.samp
# BroodYear     1.015   0.2556    2.218     6512
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location   0.02328 7.776e-10  0.09388     9409
#
#  R-structure:  ~units
#
#       post.mean  l-95% CI u-95% CI eff.samp
# units   0.01422 0.0001929  0.05343     9831
#
#  Location effects: Recruits ~ FeedRate11 + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                          post.mean  l-95% CI  u-95% CI eff.samp   pMCMC
# (Intercept)              -1.960643 -2.736824 -1.160974     7650 0.00020 ***
# FeedRate11                0.014593  0.003985  0.025360     9638 0.00701 **
# MaleAge                   0.035105 -0.049500  0.120097     9347 0.42545
# FemaleAge                 0.062231 -0.024289  0.156306     9489 0.17595
# HatchBroodSize            0.193997  0.072019  0.324981     9009 0.00200 **
# poly(HatchBroodSize, 2)2 -3.979215 -7.233836 -0.619924     9002 0.01483 *
# poly(HatchDateCode, 2)1   2.227519 -1.133637  5.432449     9245 0.18537
# poly(HatchDateCode, 2)2  -6.418378 -9.578961 -3.207982     8414 < 1e-04 ***
# Fostered                 -0.203239 -0.455454  0.044660     9260 0.10721
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Iterations = 100001:49995001
#  Thinning interval  = 5000
#  Sample size  = 9980
#
#  DIC: 1027.25
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID   0.02532 8.463e-09   0.0897     8616
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID   0.01284 1.296e-10  0.04943     9455
#
#                ~BroodYear
#
#           post.mean l-95% CI u-95% CI eff.samp
# BroodYear     1.085  0.09901    2.856     4209
#
#                ~Location
#
#          post.mean l-95% CI u-95% CI eff.samp
# Location   0.07315 4.97e-12   0.3172     7572
#
#  R-structure:  ~units
#
#       post.mean  l-95% CI u-95% CI eff.samp
# units    0.0236 0.0001441  0.09349    11271
#
#  Location effects: Recruits ~ AvgMeerkatRate + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                           post.mean   l-95% CI   u-95% CI eff.samp    pMCMC
# (Intercept)               -2.799300  -3.900644  -1.791235     8426 0.000401 ***
# AvgMeerkatRate             0.006173  -0.001007   0.012500     9683 0.073747 .
# MaleAge                    0.037011  -0.058972   0.126838     9913 0.441283
# FemaleAge                  0.025070  -0.070455   0.120402     9507 0.595190
# HatchBroodSize             0.473966   0.305442   0.644538     6677  < 1e-04 ***
# poly(HatchBroodSize, 2)2  -6.362986 -10.547753  -2.319247     7734 0.001002 **
# poly(HatchDateCode, 2)1   -1.847082  -5.169388   1.380268    10228 0.262124
# poly(HatchDateCode, 2)2   -5.188515  -8.176765  -2.085413     9557 0.000401 ***
# Fostered                  -0.313080  -0.558996  -0.062821     9980 0.015030 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Iterations = 100001:49995001
#  Thinning interval  = 5000
#  Sample size  = 9980
#
#  DIC: 981.961
#
#  G-structure:  ~MaleID
#
#        post.mean  l-95% CI u-95% CI eff.samp
# MaleID   0.02856 3.863e-10   0.1004     5445
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID   0.01236 2.504e-11  0.04696     8770
#
#                ~BroodYear
#
#           post.mean l-95% CI u-95% CI eff.samp
# BroodYear    0.9927   0.1065    2.742     6372
#
#                ~Location
#
#          post.mean l-95% CI u-95% CI eff.samp
# Location   0.08211 8.04e-12   0.3669     4651
#
#  R-structure:  ~units
#
#       post.mean  l-95% CI u-95% CI eff.samp
# units    0.0234 0.0001625  0.09554     4969
#
#  Location effects: Recruits ~ MeerkatRate7 + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                          post.mean  l-95% CI  u-95% CI eff.samp    pMCMC
# (Intercept)              -2.643117 -3.681244 -1.600048     5715 0.000200 ***
# MeerkatRate7              0.003889 -0.002001  0.010012     8316 0.207214
# MaleAge                   0.047907 -0.043161  0.142975     9168 0.305210
# FemaleAge                 0.014884 -0.084249  0.110247     8570 0.754108
# HatchBroodSize            0.464734  0.292948  0.624236     4326  < 1e-04 ***
# poly(HatchBroodSize, 2)2 -5.192545 -9.034318 -1.585455     4511 0.003607 **
# poly(HatchDateCode, 2)1  -1.946883 -5.172340  1.280732     8204 0.241483
# poly(HatchDateCode, 2)2  -4.930516 -7.918141 -2.022767     8145 0.000401 ***
# Fostered                 -0.314188 -0.564740 -0.055396     8533 0.016232 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#  Iterations = 100001:49995001
#  Thinning interval  = 5000
#  Sample size  = 9980
#
#  DIC: 1009.813
#
#  G-structure:  ~MaleID
#
#        post.mean l-95% CI u-95% CI eff.samp
# MaleID   0.02561 9.12e-10  0.08998     8080
#
#                ~FemaleID
#
#          post.mean  l-95% CI u-95% CI eff.samp
# FemaleID   0.01351 3.073e-11  0.05155     9391
#
#                ~BroodYear
#
#           post.mean l-95% CI u-95% CI eff.samp
# BroodYear     1.124   0.1062    3.067     6765
#
#                ~Location
#
#          post.mean  l-95% CI u-95% CI eff.samp
# Location   0.09713 3.424e-09   0.4369     7138
#
#  R-structure:  ~units
#
#       post.mean  l-95% CI u-95% CI eff.samp
# units   0.02137 0.0001884  0.08535     8671
#
#  Location effects: Recruits ~ MeerkatRate11 + MaleAge + FemaleAge + HatchBroodSize + poly(HatchBroodSize, 2) + poly(HatchDateCode, 2) + Fostered + HatchDateCode
#
#                           post.mean   l-95% CI   u-95% CI eff.samp    pMCMC
# (Intercept)              -2.716e+00 -3.770e+00 -1.606e+00     8497 0.000200 ***
# MeerkatRate11             4.509e-03 -8.795e-04  9.746e-03     9980 0.100802
# MaleAge                   4.729e-02 -4.445e-02  1.446e-01     9980 0.319840
# FemaleAge                 1.406e-02 -8.227e-02  1.101e-01     9980 0.768337
# HatchBroodSize            4.693e-01  3.018e-01  6.414e-01     6806  < 1e-04 ***
# poly(HatchBroodSize, 2)2 -6.441e+00 -1.044e+01 -2.315e+00     6982 0.000601 ***
# poly(HatchDateCode, 2)1  -1.311e+00 -4.298e+00  2.022e+00     9451 0.426453
# poly(HatchDateCode, 2)2  -4.992e+00 -8.085e+00 -1.988e+00     9575 0.000200 ***
# Fostered                 -2.762e-01 -5.341e-01 -2.373e-02     9980 0.034669 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
